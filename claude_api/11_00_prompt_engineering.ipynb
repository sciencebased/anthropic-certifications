# %% [markdown]
# ![alt text](images/prompt_engineering_loop.png)

# %% [markdown]
# ## Goal
# Write a prompt that generates a daschund meal plan based in their age, weight, health and dietary restrictions

# %% [markdown]
# ## Sample input
# Age : 5 years
# Weight : 10 kg
# Healt : Good
# Dietary restrictions: Lactose intolerance

# %% [markdown]
# ## Ideal output
# Here is a one day meal plan for a dashchund aiming to mantain weight and improve health
#
# Daily caloric total: Approximately 1000 calories (calculated based on height, weight, and goal)
#
# Macronutrient breakdown:
# - Protein: 60 gr
# - Carbohydrates: 120 gr
# - Fats: 20 gr
#
# Meal plan:
# - Meal 1 (7:00 AM):
#     - Chicken breast: 20gr
#     - Lactose free crockets
#     - Berries: 20 gr
# ...

# %% [markdown]
# # Tip:
# Our prompt converts out input into ideal output

# %% [markdown]
# # Tip 2:
# Be clear and direct
#
# ![alt text](images/prompt_engineering_clear_direct.png)

# %% [markdown]
# # Tip 3:
# Be specific, provide a list of guidelines or steps to direct the model
#
# ![alt text](images/prompt_engineering_specific.png)

# %% [markdown]
# # Tip 4:
# There are some guidelines types:
# - list qualities that the output should have
# - provide steps the model should follow
#
# ![alt text](images/prompt_engineering_guideline_types.png)

# %% [markdown]
# Given the tip 4, we can list qualities or provide steps

# %% [markdown]
# # When to provide steps?
# We provide steps when model to follow with these kinds of prompts:
# - troubleshooting hard problems
# - Decision making
# - Critical thinking
# - Anytime you want to force calude to consider a "wider" view

# %% [markdown]
# ![alt text](images/prompt_engineering_provide_steps.png)

# %% [markdown]
# ## When to provide list qualities?
# Almost always, generally recomended

# %% [markdown]
# ## Tip 5: Providing structure
# Use xml to separate distinct parts of prompt

# %% [markdown]
# ![alt text](images/prompt_engineering_without_xml_tags.png)

# %% [markdown]
# ![alt text](images/prompt_engineering_with_xml.png)

# %% [markdown]
# ![alt text](images/prompt_engineering_with_without_xml_tags.png)

# %% [markdown]
# ## Tip 6: Provide examples
# Give claude sample input/output
# - Useful for capturing corner cases or complet output formats
# - "One-shot": provide a single example
# - "Multi-shot": provide multiple examples
# - Highly recomended combining with xml tafs for structure

# %% [markdown]
# ![alt text](images/prompt_engineering_provide_examples.png)

# %% [markdown]
# ## REMEMBER:

# %%
<sample_input>
These are the inputs
</sample_imput>

<ideal_output>
These are the desired outputs
</ideal_output>

The reasoning behind a good output 
can be put as part of the prompt
