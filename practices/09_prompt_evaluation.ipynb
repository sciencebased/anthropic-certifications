# %% [markdown]
# ## Prompt (Engineering, evaluation)
#
# Engineering: Multishot, structured, etc
# Evaluation: Test agains, Compare verions, review errors

# %% [markdown]
#  ![alt text](images/prompt_engineering_evaluation.png)

# %% [markdown]
# # Options

# %% [markdown]
# - Test the prompt once
# - Test the prompt a few times and tweak it to handle a corner case or two
# - Run the prompt through an evaluation pipeline to score it, then iterate on the prompt
#
# ## Guess what? 1 and 2 are TRAPS

# %% [markdown]
# ## Prompt eval workflow
# - Many different ways that can be draw
# - They are many different open source modules and paid to do these
# - Draft a prompt, Create an eval dataset, feed through claude, feed through a grader, change prompt and repeat

# %% [markdown]
# ## Steps
#
# # Initial prompt draft
# Simple prompt
#
# e.g.

# %%
question = "What is a daschund?"
prompt = f"""
Please answert the user's question

{question}
"""

# %% [markdown]
# # Create eval dataset
# - Contains questions that we will merge with our prompt
# - Can be assembled by hand or generated by claude

# %%
eval_dataset = [
    "What is a daschund?",
    "Are daschunds tall",
    "Do daschunds are red?"
]

# %% [markdown]
# # Feed through claude
# Ingest -> Recieve output

# %% [markdown]
# # Feed through a grader
# There are multiple ways of creating a grader
# Recieve output -> score 1-10, based on quality
#
# After we get all the scores, we average them
#
# This is a kind of "objective" way of getting a better prompt.

# %% [markdown]
# # Change prompt and repeat
# Change the prompt and reiterate in order to get a better prompt
