# %% [markdown]
# ## Temperature
# Changes how likey each token is to be selected
#
# ![alt text](images/temperature.png)

# %% [markdown]
# ## Temperature ranges
# Low, Medium or High
# give different results, like more or less creativity, more spontaneous or more deterministic
#
# ![alt text](images/multiple_temperatures.png)

# %%
def chat(messages, system=None, temperature=1.0, stop_sequences=None):

    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature":temperature
    }
    if system:
        params["system"]=system
    if stop_sequences:
        params["stop_sequences"]=stop_sequences
    # Make a request
    message = client.messages.create(**params)
    return message.content[0].text
